# %% [markdown]
# #Import iris dataset

# %%
import pandas as pd
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %% [markdown]
# #checking for null values

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %% [markdown]
# #Drop unwanted columns

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #Visualize dataset

# %%
x=df.iloc[:, :4]
y=df.iloc[:,4]

# %%
x
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
df['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
rows, col = df.shape
print("Rows : %s, column : %s" % (rows, col))
# Out:
# Rows : 150, column : 5

# %% [markdown]
# ## Data Visualization

# %%
#snsdata = d.drop(['Id'], axis=1)
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.pairplot(df, hue='variety', markers='x')
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot)

# %%
sns.violinplot(x='sepal.length', y='variety', data=df, inner='stick', palette='autumn')
plt.show()
sns.violinplot(x='sepal.width', y='variety', data=df, inner='stick', palette='autumn')
plt.show()
sns.violinplot(x='petal.length', y='variety', data=df, inner='stick', palette='autumn')
plt.show()
sns.violinplot(x='petal.width', y='variety', data=df, inner='stick', palette='autumn')
plt.show()

# %% [markdown]
# #Split dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# #Create the ML model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# #Fit model

# %%
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-139fa7af76d2> in <cell line: 1>()
# ----> 1 model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# #Prediction

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array(['Virginica', 'Versicolor', 'Setosa', 'Virginica', 'Setosa',
#        'Virginica', 'Setosa', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Virginica', 'Versicolor', 'Versicolor', 'Versicolor',
#        'Versicolor', 'Setosa', 'Versicolor', 'Versicolor', 'Setosa',
#        'Setosa', 'Virginica', 'Versicolor', 'Setosa', 'Setosa',
#        'Virginica', 'Setosa', 'Setosa', 'Versicolor', 'Versicolor',
#        'Setosa'], dtype=object)

# %%
y_test
# Out:
# 114     Virginica
# 62     Versicolor
# 33         Setosa
# 107     Virginica
# 7          Setosa
# 100     Virginica
# 40         Setosa
# 86     Versicolor
# 76     Versicolor
# 71     Versicolor
# 134     Virginica
# 51     Versicolor
# 73     Versicolor
# 54     Versicolor
# 63     Versicolor
# 37         Setosa
# 78     Versicolor
# 90     Versicolor
# 45         Setosa
# 16         Setosa
# 121     Virginica
# 66     Versicolor
# 24         Setosa
# 8          Setosa
# 126     Virginica
# 22         Setosa
# 44         Setosa
# 97     Versicolor
# 93     Versicolor
# 26         Setosa
# Name: variety, dtype: object

# %% [markdown]
# #Confusion Matrix

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]])

# %% [markdown]
# #Accuracy

# %%
accuracy=accuracy_score(y_test,y_pred)*100
print("Accuracy of the model is {:.2f}".format(accuracy))
# Out:
# Accuracy of the model is 100.00

# %%
a = [100, 120, 105, 110]
b = ['f1', 'f2', 'f3', 'f4']
